# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
from datetime import datetime
rcParams['figure.figsize'] = (15,6)
# %pip install matplotlib
# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
my_year = 2020
my_month = 1
my_day = 2
my_hour = 13
my_min = 30
my_sec = 15
my_date = datetime(my_year,my_month,my_day,my_hour,my_min,my_sec)
print(my_date)
# Out:
# 2020-01-02 13:30:15

# %%
airline = pd.read_csv("../tmp/airline_passengers.csv",index_col="Month")
airline.dropna()
airline.index = pd.to_datetime(airline.index)
airline.plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
result = seasonal_decompose(airline['Thousands of Passengers'], model='multiplicative')
result.plot();

# %%
airline['6-month-SMA'] = airline['Thousands of Passengers'].rolling(6).mean()
airline['12-month-SMA'] = airline['Thousands of Passengers'].rolling(12).mean()
airline['EWMA-12'] = airline['Thousands of Passengers'].ewm(span=12).mean()
airline[['Thousands of Passengers','EWMA-12']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
model = SimpleExpSmoothing(airline['Thousands of Passengers'])
span = 12
alpha = 2/(span+1)
fitted = model.fit(smoothing_level=alpha, optimized=False)
airline['SES12'] = fitted.fittedvalues.shift(-1)
airline[['Thousands of Passengers','SES12']].plot(figsize=(12,5))
# Out:
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <AxesSubplot:xlabel='Month'>

# %%
airline = pd.read_csv("../tmp/airline_passengers.csv",index_col="Month")
airline.dropna()
airline.index = pd.to_datetime(airline.index)
airline.plot(figsize=(15,6))
train_data = airline.iloc[:109]
test_data = airline[108:]

from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
fitted_model = ExponentialSmoothing(train_data['Thousands of Passengers'], 
                                    trend='mul',
                                    seasonal='mul',
                                    seasonal_periods=12).fit()
# Out:
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
test_predictions = fitted_model.forecast(36)
test_predictions
# Out:
# 1958-02-01    339.142917
# 1958-03-01    399.281651
# 1958-04-01    394.233597
# 1958-05-01    402.545248
# 1958-06-01    473.128689
# 1958-07-01    521.795239
# 1958-08-01    514.513524
# 1958-09-01    446.216762
# 1958-10-01    385.430919
# 1958-11-01    339.645075
# 1958-12-01    381.455652
# 1959-01-01    401.210137
# 1959-02-01    387.159145
# 1959-03-01    455.812387
# 1959-04-01    450.049624
# 1959-05-01    459.538049
# 1959-06-01    540.114771
# 1959-07-01    595.671585
# 1959-08-01    587.358917
# 1959-09-01    509.392624
# 1959-10-01    440.000654
# 1959-11-01    387.732399
# 1959-12-01    435.462564
# 1960-01-01    458.013911
# 1960-02-01    441.973565
# 1960-03-01    520.346809
# 1960-04-01    513.768147
# 1960-05-01    524.599953
# 1960-06-01    616.584817
# 1960-07-01    680.007426
# 1960-08-01    670.517841
# 1960-09-01    581.512994
# 1960-10-01    502.296432
# 1960-11-01    442.627981
# 1960-12-01    497.115834
# 1961-01-01    522.860026
# Freq: MS, dtype: float64

# %%
train_data['Thousands of Passengers'].plot(figsize=(12,5),legend=True,label="TRAIN")
test_data['Thousands of Passengers'].plot(legend=True,label="TEST")
test_predictions.plot(legend=True,label="PREDICT",xlim=['1958-01-01','1961-01-01'])
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
test_data.describe()
# Out:
#        Thousands of Passengers
# count                36.000000
# mean                428.500000
# std                  79.329152
# min                 310.000000
# 25%                 362.000000
# 50%                 412.000000
# 75%                 472.000000
# max                 622.000000

# %%
np.sqrt(mean_squared_error(test_data, test_predictions))
# Out:
# 74.92832866139476

# %%
final_model = ExponentialSmoothing(airline['Thousands of Passengers'],
                                   trend='mul',seasonal='mul',seasonal_periods=12).fit()
final_model.fittedvalues.plot(figsize=(12,5),legend=True,label="PREDICTED")
airline['Thousands of Passengers'].plot(figsize=(15,5),legend=True,label="TRAIN")
final_model.forecast(36).plot(figsize=(15,5),legend=True,label="FORECASTED")
# Out:
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
diff(airline['Thousands of Passengers'],k_diff=1)
# Out:
# Month
# 1949-02-01     6.0
# 1949-03-01    14.0
# 1949-04-01    -3.0
# 1949-05-01    -8.0
# 1949-06-01    14.0
#               ...
# 1960-08-01   -16.0
# 1960-09-01   -98.0
# 1960-10-01   -47.0
# 1960-11-01   -71.0
# 1960-12-01    42.0
# Name: Thousands of Passengers, Length: 143, dtype: float64

# %%
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols

# %%
airline = pd.read_csv("../tmp/airline_passengers.csv",index_col="Month")
airline.dropna()
airline.index = pd.to_datetime(airline.index)
airline.index.freq = 'MS'

# %%
df = pd.DataFrame({'a':[13,5,11,12,9]})
df
# Out:
#     a
# 0  13
# 1   5
# 2  11
# 3  12
# 4   9

# %%
acf(df['a'])
# Out:
# array([ 1.   , -0.5  , -0.2  ,  0.275, -0.075])

# %%
pacf_yw(df['a'],nlags=4,method='mle')
# Out:
# array([ 1.        , -0.5       , -0.6       , -0.38541667, -0.40563273])

# %%
pacf_ols(df['a'],nlags=4)
# Out:
# array([ 1.        , -0.49677419, -0.43181818,  0.53082621,  0.25434783])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(airline['Thousands of Passengers'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(airline,lags=40);

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(airline['Thousands of Passengers'])
# Out:
# (0.815368879206063,
#  0.9918802434376413,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
from statsmodels.tools.eval_measures import mse, rmse, meanabs, aic, bic

# %%
from statsmodels.graphics.tsaplots import month_plot, quarter_plot

# %%
month_plot(airline['Thousands of Passengers']);

# %%
dfq = airline['Thousands of Passengers'].resample(rule="Q").mean()
quarter_plot(dfq);

# %%
# %pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp38-cp38-macosx_10_15_x86_64.whl (595 kB)
#      |████████████████████████████████| 595 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.24.2)
# Requirement already satisfied: numpy>=1.19.3 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: urllib3 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.26.8)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: scipy>=1.3.2 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: pandas>=0.19 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.4)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima import auto_arima

# %%
stepwise_fit = auto_arima(airline['Thousands of Passengers'],start_p=0,start_q=0,max_p=6,max_q=3,
                          seasonal=True,trace=True,
                          m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=1032.128, Time=0.19 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.12 sec
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=1019.239, Time=0.20 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.98 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=1020.493, Time=0.23 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=1032.120, Time=0.12 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=1021.120, Time=0.22 sec
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=1021.032, Time=0.29 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=1019.178, Time=0.17 sec
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=1020.425, Time=0.07 sec
#  ARIMA(0,1,1)(2,1,1)[12]             : AIC=inf, Time=0.81 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=1020.327, Time=0.21 sec
#  ARIMA(0,1,2)(2,1,0)[12]             : AIC=1021.148, Time=0.17 sec
#  ARIMA(1,1,2)(2,1,0)[12]             : AIC=1022.805, Time=0.34 sec
#  ARIMA(0,1,1)(2,1,0)[12] intercept   : AIC=1021.017, Time=0.32 sec
#
# Best model:  ARIMA(0,1,1)(2,1,0)[12]
# Total fit time: 4.636 seconds
# /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1

# %%
stepwise_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:               SARIMAX(4, 1, 3)   Log Likelihood                -674.913
# Date:                Thu, 21 Jul 2022   AIC                           1365.825
# Time:                        20:12:45   BIC                           1389.528
# Sample:                             0   HQIC                          1375.457
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5582      0.117     -4.782      0.000      -0.787      -0.329
# ar.L2          0.4935      0.113      4.375      0.000       0.272       0.715
# ar.L3          0.1238      0.128      0.970      0.332      -0.126       0.374
# ar.L4         -0.5213      0.085     -6.136      0.000      -0.688      -0.355
# ma.L1          0.9069      0.094      9.657      0.000       0.723       1.091
# ma.L2         -0.5590      0.145     -3.866      0.000      -0.842      -0.276
# ma.L3         -0.7385      0.109     -6.778      0.000      -0.952      -0.525
# sigma2       724.1727     85.616      8.458      0.000     556.369     891.976
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                14.59
# Prob(Q):                              0.54   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.66   Skew:                             0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# %pip install prophet
from prophet import Prophet
# Out:
# Requirement already satisfied: prophet in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (1.1)
# Requirement already satisfied: setuptools>=42 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (61.2.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (1.21.5)
# Requirement already satisfied: wheel>=0.37.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (0.37.1)
# Requirement already satisfied: holidays>=0.13 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (0.14.2)
# Requirement already satisfied: convertdate>=2.1.2 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (2.4.0)
# Requirement already satisfied: Cython>=0.22 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (0.29.28)
# Requirement already satisfied: pandas>=1.0.4 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (1.4.1)
# Requirement already satisfied: cmdstanpy>=1.0.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (1.0.4)
# Requirement already satisfied: setuptools-git>=1.2 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (1.2)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (4.63.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (0.0.9)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from prophet) (3.5.1)
# Requirement already satisfied: ujson in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from cmdstanpy>=1.0.1->prophet) (5.1.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from convertdate>=2.1.2->prophet) (0.5.11)
# Requirement already satisfied: hijri-converter in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.13->prophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from holidays>=0.13->prophet) (0.2.1)
# Requirement already satisfied: pytz in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from LunarCalendar>=0.0.9->prophet) (2021.3)
# Requirement already satisfied: ephem>=3.7.5.3 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/oawofolu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('../tmp/BeerWineLiquor.csv')

# %%
df.columns = ['ds','y']
df['ds'] = pd.to_datetime(df['ds'])
df
# Out:
#             ds     y
# 0   1992-01-01  1509
# 1   1992-02-01  1541
# 2   1992-03-01  1597
# 3   1992-04-01  1675
# 4   1992-05-01  1822
# ..         ...   ...
# 319 2018-08-01  4898
# 320 2018-09-01  4598
# 321 2018-10-01  4737
# 322 2018-11-01  5130
# 323 2018-12-01  6370
#
# [324 rows x 2 columns]

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=24,freq='MS')
future.tail()
forecast = m.predict(future)
forecast
# Out:
# 22:27:27 - cmdstanpy - INFO - Chain [1] start processing
# 22:27:27 - cmdstanpy - INFO - Chain [1] done processing
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   1992-01-01  1776.981570  1155.088471  1478.837939  1776.981570
# 1   1992-02-01  1779.641479  1198.382457  1521.443743  1779.641479
# 2   1992-03-01  1782.129782  1439.863577  1761.124055  1782.129782
# 3   1992-04-01  1784.789691  1426.338599  1748.080932  1784.789691
# 4   1992-05-01  1787.363797  1672.719074  1998.035241  1787.363797
# ..         ...          ...          ...          ...          ...
# 343 2020-08-01  5206.549110  5082.981945  5409.601260  5196.372438
# 344 2020-09-01  5222.727568  4928.934413  5249.743523  5211.658461
# 345 2020-10-01  5238.384141  5037.077433  5350.841755  5226.370447
# 346 2020-11-01  5254.562599  5177.449904  5501.003376  5241.876963
# 347 2020-12-01  5270.219171  6179.842513  6502.385793  5256.799647
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    1776.981570     -461.915356           -461.915356           -461.915356
# 1    1779.641479     -427.834134           -427.834134           -427.834134
# 2    1782.129782     -179.552026           -179.552026           -179.552026
# 3    1784.789691     -196.028718           -196.028718           -196.028718
# 4    1787.363797       45.788878             45.788878             45.788878
# ..           ...             ...                   ...                   ...
# 343  5219.637771       40.750878             40.750878             40.750878
# 344  5236.748676     -132.602089           -132.602089           -132.602089
# 345  5253.428628      -43.253760            -43.253760            -43.253760
# 346  5270.865961       87.468083             87.468083             87.468083
# 347  5287.354875     1071.204478           1071.204478           1071.204478
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -461.915356   -461.915356   -461.915356                   0.0
# 1    -427.834134   -427.834134   -427.834134                   0.0
# 2    -179.552026   -179.552026   -179.552026                   0.0
# 3    -196.028718   -196.028718   -196.028718                   0.0
# 4      45.788878     45.788878     45.788878                   0.0
# ..           ...           ...           ...                   ...
# 343    40.750878     40.750878     40.750878                   0.0
# 344  -132.602089   -132.602089   -132.602089                   0.0
# 345   -43.253760    -43.253760    -43.253760                   0.0
# 346    87.468083     87.468083     87.468083                   0.0
# 347  1071.204478   1071.204478   1071.204478                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                           0.0                         0.0  1315.066214
# 1                           0.0                         0.0  1351.807345
# 2                           0.0                         0.0  1602.577756
# 3                           0.0                         0.0  1588.760974
# 4                           0.0                         0.0  1833.152675
# ..                          ...                         ...          ...
# 343                         0.0                         0.0  5247.299989
# 344                         0.0                         0.0  5090.125480
# 345                         0.0                         0.0  5195.130381
# 346                         0.0                         0.0  5342.030682
# 347                         0.0                         0.0  6341.423649
#
# [348 rows x 16 columns]

# %%
forecast.plot(x='ds',y='yhat',figsize=(12,8))
plt.xlim('2014-01-01','2021-01-01')
# Out:
# (528.0, 612.0)
